# %% [markdown]
# # Acoustic Extinguisher Fire Dataset

# %% [markdown]
# ### SHORT DESCRIPTION:

# %% [markdown]
# The dataset was obtained as a result of the extinguishing tests of four different fuel flames with a sound wave extinguishing system. The sound wave fire-extinguishing system consists of 4 subwoofers with a total power of 4,000 Watt placed in the collimator cabinet. There are two amplifiers that enable the sound come to these subwoofers as boosted. Power supply that powers the system and filter circuit ensuring that the sound frequencies are properly transmitted to the system is located within the control unit. While computer is used as frequency source, anemometer was used to measure the airflow resulted from sound waves during the extinguishing phase of the flame, and a decibel meter to measure the sound intensity. An infrared thermometer was used to measure the temperature of the flame and the fuel can, and a camera is installed to detect the extinction time of the flame. A total of 17,442 tests were conducted with this experimental setup.

# %% [markdown]
# Data properties and descriptions for liquid fuels
# FEATURES MIN/MAX VALUES UNIT DESCRIPTIONS
# SIZE 7, 12, 14, 16, 20 cm Recorded as 7 cm=1, 12 cm=2, 14 cm=3, 16 cm=4, 20 cm=5
# FUEL Gasoline, Kerosene, Thinner Fuel type
# DISTANCE 10 - 190 cm
# DESIBEL 72 - 113 dB
# AIRFLOW 0 - 17 m/s
# FREQUENCY 1-75 Hz
# STATUS 0, 1
# 0 indicates the non-extinction state, 1 indicates the extinction state
#
# Data properties and descriptions for LPG
# FEATURES MIN/MAX VALUES UNIT DESCRIPTIONS
# SIZE Half throttle setting, Full throttle setting Reocerded as Half throttle setting=6, Full throttle setting=7
# FUEL LPG Fuel type
# DISTANCE 10 - 190 cm
# DESIBEL 72 - 113 dB
# AIRFLOW 0 - 17 m/s
# FREQUENCY 1-75 Hz

# %% [markdown]
# ![A-Sonic-Fire-Extinguisher-Extinguish-Fire-by-Sound-Waves.jpg](attachment:A-Sonic-Fire-Extinguisher-Extinguish-Fire-by-Sound-Waves.jpg)

# %% [markdown]
# Acoustic Fire Extinguisher is a type of fire extinguisher which uses sound waves to extinguish the fire rather than using the chemical compounds used by traditional fire extinguishers.This type of extinguisher can be more safe than the traditional ones as it doesn't use any chemical compounds which can cause health risks or property damage. With the current development, Acoustic Fire Extinguisher is able to put off small fires but it's a great development for the start.

# %% [markdown]
# ## Little Science behind

# %% [markdown]
# ![afe.jpg](attachment:afe.jpg)

# %% [markdown]
# By focusing bass sound waves into a specific direction, the acoustic fire extinguisher ability to manipulate both oxygen and burning material is maximized. Because sound is a pressure wave that oscillates between regions of high and low pressure, the oscillation can be exploited to create a vacuum that separates air molecules from the sounds of the flame, putting out the fire.

# %% [markdown]
# ### Here we Analyse the effect of different frequency of a sound wave on diffrent fuel flames.

# %% [markdown]
# ### Let's move on to the analysis

# %% [markdown]
# ## Importing The Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading and Viewing the Data

# %%
d=pd.read_excel('Acoustic_Dataset.xlsx')
d
# Out:
#        SIZE      FUEL  DISTANCE  DESIBEL  AIRFLOW  FREQUENCY  STATUS
# 0         1  gasoline        10       96      0.0         75       0
# 1         1  gasoline        10       96      0.0         72       1
# 2         1  gasoline        10       96      2.6         70       1
# 3         1  gasoline        10       96      3.2         68       1
# 4         1  gasoline        10      109      4.5         67       1
# ...     ...       ...       ...      ...      ...        ...     ...
# 17437     7       lpg       190       86      2.2          5       0
# 17438     7       lpg       190       84      2.0          4       0
# 17439     7       lpg       190       80      1.5          3       0
# 17440     7       lpg       190       76      0.4          2       0
# 17441     7       lpg       190       72      0.0          1       0
#
# [17442 rows x 7 columns]

# %% [markdown]
# ## Basic Information

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17442 entries, 0 to 17441
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SIZE       17442 non-null  int64
#  1   FUEL       17442 non-null  object
#  2   DISTANCE   17442 non-null  int64
#  3   DESIBEL    17442 non-null  int64
#  4   AIRFLOW    17442 non-null  float64
#  5   FREQUENCY  17442 non-null  int64
#  6   STATUS     17442 non-null  int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 954.0+ KB

# %% [markdown]
# ## Shape of the Data

# %%
d.shape
# Out:
# (17442, 7)

# %% [markdown]
# ## Statistical Information

# %%
d.describe()
# Out:
#                SIZE      DISTANCE       DESIBEL       AIRFLOW     FREQUENCY  \
# count  17442.000000  17442.000000  17442.000000  17442.000000  17442.000000
# mean       3.411765    100.000000     96.379142      6.975634     31.611111
# std        1.750977     54.773826      8.164096      4.736169     20.939149
# min        1.000000     10.000000     72.000000      0.000000      1.000000
# 25%        2.000000     50.000000     90.000000      3.200000     14.000000
# 50%        3.000000    100.000000     95.000000      5.800000     27.500000
# 75%        5.000000    150.000000    104.000000     11.200000     47.000000
# max        7.000000    190.000000    113.000000     17.000000     75.000000
#
#              STATUS
# count  17442.000000
# mean       0.497821
# std        0.500010
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %% [markdown]
# ## Checking if the Dataset contains Nullvalues

# %%
d.isnull().sum()
# Out:
# SIZE         0
# FUEL         0
# DISTANCE     0
# DESIBEL      0
# AIRFLOW      0
# FREQUENCY    0
# STATUS       0
# dtype: int64

# %% [markdown]
# ## Checking Datatypes

# %%
d.dtypes
# Out:
# SIZE           int64
# FUEL          object
# DISTANCE       int64
# DESIBEL        int64
# AIRFLOW      float64
# FREQUENCY      int64
# STATUS         int64
# dtype: object

# %% [markdown]
# ## Correlation and Covariance

# %%
d.corr()
# Out:
#                    SIZE      DISTANCE       DESIBEL       AIRFLOW  \
# SIZE       1.000000e+00 -2.437871e-15 -6.125585e-15  1.677898e-16
# DISTANCE  -2.437871e-15  1.000000e+00 -2.385897e-01 -7.074906e-01
# DESIBEL   -6.125585e-15 -2.385897e-01  1.000000e+00  3.769153e-01
# AIRFLOW    1.677898e-16 -7.074906e-01  3.769153e-01  1.000000e+00
# FREQUENCY  9.978281e-17 -2.452947e-17  5.617409e-01 -2.120462e-01
# STATUS    -9.694718e-02 -6.440506e-01  2.039698e-01  7.606279e-01
#
#               FREQUENCY    STATUS
# SIZE       9.978281e-17 -0.096947
# DISTANCE  -2.452947e-17 -0.644051
# DESIBEL    5.617409e-01  0.203970
# AIRFLOW   -2.120462e-01  0.760628
# FREQUENCY  1.000000e+00 -0.244203
# STATUS    -2.442030e-01  1.000000

# %%
d.cov()
# Out:
#                    SIZE      DISTANCE       DESIBEL       AIRFLOW  \
# SIZE       3.065920e+00 -1.407967e-15  2.607347e-17  7.822040e-17
# DISTANCE  -1.407967e-15  3.000172e+03 -1.066923e+02 -1.835359e+02
# DESIBEL    2.607347e-17 -1.066923e+02  6.665247e+01  1.457401e+01
# AIRFLOW    7.822040e-17 -1.835359e+02  1.457401e+01  2.243130e+01
# FREQUENCY -1.694775e-16 -8.343510e-16  9.602917e+01 -2.102891e+01
# STATUS    -8.487776e-02 -1.763890e+01  8.326304e-01  1.801266e+00
#
#               FREQUENCY     STATUS
# SIZE      -1.694775e-16  -0.084878
# DISTANCE  -8.343510e-16 -17.638897
# DESIBEL    9.602917e+01   0.832630
# AIRFLOW   -2.102891e+01   1.801266
# FREQUENCY  4.384480e+02  -2.556750
# STATUS    -2.556750e+00   0.250010

# %% [markdown]
# ## How many Values of 'Status' and 'Fuel' columns

# %%
d['STATUS'].value_counts()
# Out:
# 0    8759
# 1    8683
# Name: STATUS, dtype: int64

# %%
d['FUEL'].value_counts()
# Out:
# gasoline    5130
# thinner     5130
# kerosene    5130
# lpg         2052
# Name: FUEL, dtype: int64

# %% [markdown]
# There are 3 types of fuels which were used to create fire for the acoustic ext. to work on:
# * Gasoline
# * Thinner
# * Kerosene
# * Lpg

# %% [markdown]
# ## Visualization

# %%
sns.countplot(d['STATUS'], label="Count")
plt.show()

# %%
sns.countplot(d['FUEL'], label="Count")
plt.show()

# %% [markdown]
# lpg has low count compared to remaining fuel

# %%
sns.countplot(d.FUEL.loc[d['STATUS'] == 1], label="Count")
plt.show()

# %% [markdown]
# gasoline have higher count with extinction state

# %%
sns.countplot(d.FUEL.loc[d['STATUS'] == 0], label="Count")
plt.show()

# %% [markdown]
# gasoline have the higher count when extinction state and while kerosene have higher count in non-extinction state

# %%
d['FUEL'].value_counts().plot(kind="pie",autopct="%.2f%%")
plt.show()

# %%
plt.figure()
sns.heatmap(d.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.bar(d.columns,d.nunique())
plt.show()

# %%
plt.figure(figsize=[10, 8])
sns.countplot(d['SIZE'])
plt.show()

# %% [markdown]
# We see most of the sizes of Liquid Fuel Cans fall in 1 to 5 with an equal count.

# %%
sns.pairplot(d)
plt.show()

# %% [markdown]
# ## Categorical Transformation

# %%
from sklearn.preprocessing import LabelEncoder
for i in d.columns:
    if d[i].dtypes == 'object':
        d[i] = LabelEncoder().fit_transform(d[i])

# %% [markdown]
# d['FUEL'] = d['FUEL'].astype('int')

# %%
d.dtypes
# Out:
# SIZE           int64
# FUEL           int32
# DISTANCE       int64
# DESIBEL        int64
# AIRFLOW      float64
# FREQUENCY      int64
# STATUS         int64
# dtype: object

# %% [markdown]
# ## Taking the variables

# %%
x = d.drop(['STATUS'],axis=1)
x
# Out:
#        SIZE  FUEL  DISTANCE  DESIBEL  AIRFLOW  FREQUENCY
# 0         1     0        10       96      0.0         75
# 1         1     0        10       96      0.0         72
# 2         1     0        10       96      2.6         70
# 3         1     0        10       96      3.2         68
# 4         1     0        10      109      4.5         67
# ...     ...   ...       ...      ...      ...        ...
# 17437     7     2       190       86      2.2          5
# 17438     7     2       190       84      2.0          4
# 17439     7     2       190       80      1.5          3
# 17440     7     2       190       76      0.4          2
# 17441     7     2       190       72      0.0          1
#
# [17442 rows x 6 columns]

# %%
y = d.STATUS
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 17437    0
# 17438    0
# 17439    0
# 17440    0
# 17441    0
# Name: STATUS, Length: 17442, dtype: int64

# %% [markdown]
# ## Train and test data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=101)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (12209, 6)
# (12209,)
# (5233, 6)
# (5233,)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logistic_model = LogisticRegression()
logistic_model.fit(x_train,y_train)
y_predict = logistic_model.predict(x_test)

# %%
print("Training Accuracy of Logistic Regression Model is :", logistic_model.score(x_train,y_train))
print("Test Accuracy of Logistic Regression Model is :", logistic_model.score(x_test,y_test))
# Out:
# Training Accuracy of Logistic Regression Model is : 0.8777950692112376
# Test Accuracy of Logistic Regression Model is : 0.8710108924135295

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import accuracy_score
performance = confusion_matrix(y_test,y_predict)

plot_confusion_matrix(logistic_model,x_test,y_test)
plt.show()
print('Accuracy of model:',accuracy_score(y_test,y_predict))
# Out:
# Accuracy of model: 0.8710108924135295

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87      2619
#            1       0.88      0.85      0.87      2614
#
#     accuracy                           0.87      5233
#    macro avg       0.87      0.87      0.87      5233
# weighted avg       0.87      0.87      0.87      5233

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
print("Training Accuracy of Random Forest Classifier is :", rfc.score(x_train,y_train))
print("Test Accuracy of Random Forest Classifier is :", rfc.score(x_test,y_test))
# Out:
# Training Accuracy of Random Forest Classifier is : 1.0
# Test Accuracy of Random Forest Classifier is : 0.9577680107013186

# %%
y_predict =rfc.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

performance = confusion_matrix(y_test,y_predict)

plot_confusion_matrix(rfc,x_test,y_test)
plt.show()
print('Accuracy of model:',accuracy_score(y_test,y_predict))
# Out:
# Accuracy of model: 0.9577680107013186

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      2619
#            1       0.96      0.95      0.96      2614
#
#     accuracy                           0.96      5233
#    macro avg       0.96      0.96      0.96      5233
# weighted avg       0.96      0.96      0.96      5233

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Training Accuracy of Decision Tree Classifier is :", dt.score(x_train,y_train))
print("Test Accuracy of Decision Tree Classifier is :", dt.score(x_test,y_test))
# Out:
# Training Accuracy of Decision Tree Classifier is : 1.0
# Test Accuracy of Decision Tree Classifier is : 0.9594878654691381

# %%
y_predict = dt.predict(x_test)
y_predict
# Out:
# array([0, 1, 0, ..., 0, 0, 1], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import accuracy_score

performance = confusion_matrix(y_test,y_predict)

plot_confusion_matrix(dt,x_test,y_test)
plt.show()
print('Accuracy of model:',accuracy_score(y_test,y_predict))
# Out:
# Accuracy of model: 0.9594878654691381

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      2619
#            1       0.96      0.96      0.96      2614
#
#     accuracy                           0.96      5233
#    macro avg       0.96      0.96      0.96      5233
# weighted avg       0.96      0.96      0.96      5233

# %% [markdown]
# ## K Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Training Accuracy of K Neighbors Classifier is :", knn.score(x_train,y_train))
print("Test Accuracy of K Neighbors Classifier is :", knn.score(x_test,y_test))
# Out:
# Training Accuracy of K Neighbors Classifier is : 0.9427471537390449
# Test Accuracy of K Neighbors Classifier is : 0.9117141219185936

# %%
y_predict = knn.predict(x_test)
y_predict
# Out:
# array([0, 1, 0, ..., 0, 0, 1], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import accuracy_score

performance = confusion_matrix(y_test,y_predict)

plot_confusion_matrix(knn,x_test,y_test)
plt.show()
print('Accuracy of model:',accuracy_score(y_test,y_predict))
# Out:
# Accuracy of model: 0.9117141219185936

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91      2619
#            1       0.92      0.90      0.91      2614
#
#     accuracy                           0.91      5233
#    macro avg       0.91      0.91      0.91      5233
# weighted avg       0.91      0.91      0.91      5233

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
print("Training Accuracy of SVC is :", svc.score(x_train,y_train))
print("Test Accuracy of SVC is :", svc.score(x_test,y_test))
# Out:
# Training Accuracy of SVC is : 0.8903268080923908
# Test Accuracy of SVC is : 0.8849608255302885

# %%
y_predict = svc.predict(x_test)
y_predict
# Out:
# array([0, 1, 0, ..., 0, 0, 1], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

performance = confusion_matrix(y_test,y_predict)

plot_confusion_matrix(svc,x_test,y_test)
plt.show()
print('Accuracy of model:',accuracy_score(y_test,y_predict))
# Out:
# Accuracy of model: 0.8849608255302885

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.89      2619
#            1       0.90      0.87      0.88      2614
#
#     accuracy                           0.88      5233
#    macro avg       0.89      0.88      0.88      5233
# weighted avg       0.89      0.88      0.88      5233

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
print("Training Accuracy  is :", nb.score(x_train,y_train))
print("Test Accuracy  is :", nb.score(x_test,y_test))
# Out:
# Training Accuracy  is : 0.872716848226718
# Test Accuracy  is : 0.8668068029810816

# %%
y_predict = nb.predict(x_test)
y_predict
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

performance = confusion_matrix(y_test,y_predict)

plot_confusion_matrix(svc,x_test,y_test)
plt.show()
print('Accuracy of model:',accuracy_score(y_test,y_predict))
# Out:
# Accuracy of model: 0.8668068029810816

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      2619
#            1       0.89      0.84      0.86      2614
#
#     accuracy                           0.87      5233
#    macro avg       0.87      0.87      0.87      5233
# weighted avg       0.87      0.87      0.87      5233

# %% [markdown]
# ## From all the models Best Model is RandomForestClassifier and the Accuracy of model is 0.96
